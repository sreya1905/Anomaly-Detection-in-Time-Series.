# %% [markdown]
# # 1. AMAZON

# %%
#import libraries which are necessery

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read dataset 
df=pd.read_csv(r"Amazon.csv")

# %%
#calls dataset
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-01-02   312.579987   314.750000   306.959991   308.519989
# 1     2015-01-05   307.010010   308.380005   300.850006   302.190002
# 2     2015-01-06   302.239990   303.000000   292.380005   295.290009
# 3     2015-01-07   297.500000   301.279999   295.329987   298.420013
# 4     2015-01-08   300.320007   303.140015   296.109985   300.459991
# ...          ...          ...          ...          ...          ...
# 1756  2021-12-22  3385.399902  3441.000000  3370.010010  3420.739990
# 1757  2021-12-23  3408.560059  3439.500000  3403.000000  3421.370117
# 1758  2021-12-27  3420.739990  3458.860107  3384.310059  3393.389893
# 1759  2021-12-28  3403.649902  3443.520020  3382.709961  3413.219971
# 1760  2021-12-29  3416.800049  3424.239990  3372.010010  3384.020020
#
#         Adj Close   Volume
# 0      308.519989  2783200
# 1      302.190002  2774200
# 2      295.290009  3519000
# ...

# %%
#returns description of data in dataframe
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean   1656.975390  1674.000896  1637.994066  1656.407234  1656.407234
# std    1007.431401  1018.769282   994.943941  1006.561544  1006.561544
# min     286.279999   290.790009   285.250000   286.950012   286.950012
# 25%     766.599976   771.219971   761.200012   767.330017   767.330017
# 50%    1604.000000  1623.560059  1590.869995  1603.069946  1603.069946
# 75%    2125.020020  2159.040039  2088.000000  2134.870117  2134.870117
# max    3744.000000  3773.080078  3696.790039  3731.409912  3731.409912
#
#              Volume
# count  1.761000e+03
# mean   4.184049e+06
# std    2.129974e+06
# min    8.813000e+05
# 25%    2.792400e+06
# 50%    3.614500e+06
# 75%    4.922200e+06
# max    2.385610e+07

# %%
#prints information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
#checks if there is any null value
df.isnull()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1756  False  False  False  False  False      False   False
# 1757  False  False  False  False  False      False   False
# 1758  False  False  False  False  False      False   False
# 1759  False  False  False  False  False      False   False
# 1760  False  False  False  False  False      False   False
#
# [1761 rows x 7 columns]

# %%
#checks if there is any null value and returns sum of it.
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#gets column names
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#defines a list
c=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
#loop is given here to get boxplots of the given column datas to find outliers
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %% [markdown]
# # Manage outliers

# %%
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
amazon_c=df
amazon_c.to_csv("amazon c.csv",index=False)

# %% [markdown]
# # 2. APPLE

# %%
#import libraries which are necessery

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read dataset 
df=pd.read_csv(r"Apple.csv")

# %%
#calls dataset
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   27.847500   27.860001   26.837500   27.332500   24.745996
# 1     2015-01-05   27.072500   27.162500   26.352501   26.562500   24.048864
# 2     2015-01-06   26.635000   26.857500   26.157499   26.565001   24.051125
# 3     2015-01-07   26.799999   27.049999   26.674999   26.937500   24.388372
# 4     2015-01-08   27.307501   28.037500   27.174999   27.972500   25.325430
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  173.039993  175.860001  172.149994  175.639999  175.639999
# 1757  2021-12-23  175.850006  176.850006  175.270004  176.279999  176.279999
# 1758  2021-12-27  177.089996  180.419998  177.070007  180.330002  180.330002
# 1759  2021-12-28  180.160004  181.330002  178.529999  179.289993  179.289993
# 1760  2021-12-29  179.330002  180.630005  178.139999  179.380005  179.380005
#
#          Volume
# 0     212818400
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean     61.215403    61.869735    60.587250    61.260216    59.790383
# std      40.132857    40.624631    39.659062    40.171980    40.755287
# min      22.500000    22.917500    22.367500    22.584999    21.036304
# 25%      31.510000    31.735001    31.242500    31.475000    28.694981
# 50%      43.860001    44.325001    43.625000    43.962502    42.401981
# 75%      76.809998    77.942497    76.072502    77.377502    76.244965
# max     181.119995   182.130005   178.529999   180.330002   180.330002
#
#              Volume
# count  1.761000e+03
# mean   1.381024e+08
# std    6.977506e+07
# min    4.100000e+07
# 25%    9.075730e+07
# 50%    1.189944e+08
# 75%    1.654288e+08
# max    6.488252e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
c=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
#loop is given here to get boxplots of the given column datas to find outliers
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Open"],25,interpolation="midpoint")
Q2=np.percentile(df["Open"],50,interpolation="midpoint")
Q3=np.percentile(df["Open"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Open"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Open']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Open']=up_lim
sns.boxplot(df["Open"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open'>

# %%
Q1=np.percentile(df["High"],25,interpolation="midpoint")
Q2=np.percentile(df["High"],50,interpolation="midpoint")
Q3=np.percentile(df["High"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["High"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['High']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'High']=up_lim
sns.boxplot(df["High"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
Q1=np.percentile(df["Low"],25,interpolation="midpoint")
Q2=np.percentile(df["Low"],50,interpolation="midpoint")
Q3=np.percentile(df["Low"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Low"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Low']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Low']=up_lim
sns.boxplot(df["Low"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
Q1=np.percentile(df["Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Close']=up_lim
sns.boxplot(df["Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
Q1=np.percentile(df["Adj Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Adj Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Adj Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Adj Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Adj Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Adj Close']=up_lim
sns.boxplot(df["Adj Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Adj Close'>

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
apple_c=df
apple_c.to_csv("apple c.csv",index=False)

# %% [markdown]
# # 3. FACEBOOK

# %%
df=pd.read_csv(r"Facebook.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   78.580002   78.930000   77.699997   78.449997   78.449997
# 1     2015-01-05   77.980003   79.250000   76.860001   77.190002   77.190002
# 2     2015-01-06   77.230003   77.589996   75.360001   76.150002   76.150002
# 3     2015-01-07   76.760002   77.360001   75.820000   76.150002   76.150002
# 4     2015-01-08   76.739998   78.230003   76.080002   78.180000   78.180000
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  333.799988  334.510010  328.260010  330.450012  330.450012
# 1757  2021-12-23  330.100006  336.670013  328.359985  335.239990  335.239990
# 1758  2021-12-27  338.850006  347.869995  338.010010  346.179993  346.179993
# 1759  2021-12-28  346.630005  352.709991  345.200012  346.220001  346.220001
# 1760  2021-12-29  346.910004  349.690002  341.640015  342.940002  342.940002
#
#         Volume
# 0     18177500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean    181.409466   183.492499   179.313095   181.476928   181.476928
# std      75.109523    76.106086    74.183342    75.143460    75.143460
# min      74.040001    74.830002    72.000000    74.050003    74.050003
# 25%     123.099998   124.260002   122.309998   123.410004   123.410004
# 50%     171.789993   173.240005   169.559998   171.470001   171.470001
# 75%     210.190002   211.619995   208.710007   210.850006   210.850006
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  1.761000e+03
# mean   2.206907e+07
# std    1.292301e+07
# min    5.913100e+06
# 25%    1.437970e+07
# 50%    1.887410e+07
# 75%    2.521830e+07
# max    1.698037e+08

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
c=[ 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Open"],25,interpolation="midpoint")
Q2=np.percentile(df["Open"],50,interpolation="midpoint")
Q3=np.percentile(df["Open"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Open"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Open']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Open']=up_lim
sns.boxplot(df["Open"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open'>

# %%
Q1=np.percentile(df["High"],25,interpolation="midpoint")
Q2=np.percentile(df["High"],50,interpolation="midpoint")
Q3=np.percentile(df["High"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["High"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['High']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'High']=up_lim
sns.boxplot(df["High"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
Q1=np.percentile(df["Low"],25,interpolation="midpoint")
Q2=np.percentile(df["Low"],50,interpolation="midpoint")
Q3=np.percentile(df["Low"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Low"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Low']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Low']=up_lim
sns.boxplot(df["Low"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
Q1=np.percentile(df["Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Close']=up_lim
sns.boxplot(df["Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
Q1=np.percentile(df["Adj Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Adj Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Adj Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Adj Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Adj Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Adj Close']=up_lim
sns.boxplot(df["Adj Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Adj Close'>

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(16,9))

sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
facebook_c=df
facebook_c.to_csv("facebook c.csv",index=False)

# %% [markdown]
# # 4. GOOGLE

# %%
df=pd.read_csv(r"Google.csv")

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-01-02   527.561584   529.815369   522.665039   523.373108
# 1     2015-01-05   521.827332   522.894409   511.655243   512.463013
# 2     2015-01-06   513.589966   514.761719   499.678131   500.585632
# 3     2015-01-07   505.611847   505.855164   498.281952   499.727997
# 4     2015-01-08   496.626526   502.101471   489.655640   501.303680
# ...          ...          ...          ...          ...          ...
# 1756  2021-12-22  2882.000000  2946.060059  2879.260010  2938.979980
# 1757  2021-12-23  2941.790039  2971.451904  2939.017090  2942.850098
# 1758  2021-12-27  2949.270020  2968.530029  2945.000000  2961.280029
# 1759  2021-12-28  2967.489990  2967.489990  2918.709961  2928.959961
# 1760  2021-12-29  2928.590088  2943.675049  2910.090088  2930.090088
#
#         Adj Close   Volume
# 0      523.373108  1447563
# 1      512.463013  2059840
# 2      500.585632  2899940
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean   1220.630527  1232.290406  1209.582267  1221.454750  1221.454750
# std     610.890123   616.593351   605.804613   611.531027   611.531027
# min     493.295654   494.618011   486.225067   491.201416   491.201416
# 25%     774.250000   779.530029   768.794983   772.880005   772.880005
# 50%    1082.469971  1094.170044  1070.000000  1082.479980  1082.479980
# 75%    1390.800049  1411.579956  1377.151978  1393.339966  1393.339966
# max    3020.000000  3037.000000  2997.750000  3014.179932  3014.179932
#
#              Volume
# count  1.761000e+03
# mean   1.671220e+06
# std    8.150576e+05
# min    3.468000e+05
# 25%    1.191400e+06
# 50%    1.466700e+06
# 75%    1.907200e+06
# max    1.116490e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
c=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Open"],25,interpolation="midpoint")
Q2=np.percentile(df["Open"],50,interpolation="midpoint")
Q3=np.percentile(df["Open"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Open"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Open']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Open']=up_lim
sns.boxplot(df["Open"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open'>

# %%
Q1=np.percentile(df["High"],25,interpolation="midpoint")
Q2=np.percentile(df["High"],50,interpolation="midpoint")
Q3=np.percentile(df["High"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["High"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['High']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'High']=up_lim
sns.boxplot(df["High"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
Q1=np.percentile(df["Low"],25,interpolation="midpoint")
Q2=np.percentile(df["Low"],50,interpolation="midpoint")
Q3=np.percentile(df["Low"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Low"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Low']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Low']=up_lim
sns.boxplot(df["Low"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
Q1=np.percentile(df["Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Close']=up_lim
sns.boxplot(df["Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
Q1=np.percentile(df["Adj Close"],25,interpolation="midpoint")
Q2=np.percentile(df["Adj Close"],50,interpolation="midpoint")
Q3=np.percentile(df["Adj Close"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Adj Close"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Adj Close']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Adj Close']=up_lim
sns.boxplot(df["Adj Close"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Adj Close'>

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
google_c=df
google_c.to_csv("google c.csv",index=False)

# %% [markdown]
# # 5. MICROSOFT

# %%
df=pd.read_csv(r"Microsoft.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   46.660000   47.419998   46.540001   46.759998   41.193840
# 1     2015-01-05   46.369999   46.730000   46.250000   46.330002   40.815037
# 2     2015-01-06   46.380001   46.750000   45.540001   45.650002   40.215973
# 3     2015-01-07   45.980000   46.459999   45.490002   46.230000   40.726925
# 4     2015-01-08   46.750000   47.750000   46.720001   47.590000   41.925045
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  328.299988  333.609985  325.750000  333.200012  333.200012
# 1757  2021-12-23  332.750000  336.390015  332.730011  334.690002  334.690002
# 1758  2021-12-27  335.459991  342.480011  335.429993  342.450012  342.450012
# 1759  2021-12-28  343.149994  343.809998  340.320007  341.250000  341.250000
# 1760  2021-12-29  341.299988  344.299988  339.679993  341.950012  341.950012
#
#         Volume
# 0     27913900
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean    124.677956   125.841812   123.491261   124.746269   121.222532
# std      79.037039    79.783672    78.305072    79.115307    80.389635
# min      40.340000    40.740002    39.720001    40.290001    35.590923
# 25%      57.880001    58.090000    57.450001    57.889999    53.343620
# 50%     101.099998   101.860001    99.629997   101.120003    97.076530
# 75%     174.110001   175.059998   170.820007   174.050003   171.117706
# max     344.619995   349.670013   342.200012   343.109985   343.109985
#
#              Volume
# count  1.761000e+03
# mean   2.991662e+07
# std    1.416212e+07
# min    7.425600e+06
# 25%    2.138430e+07
# 50%    2.640770e+07
# 75%    3.397970e+07
# max    1.691640e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
c=[ 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Low"],25,interpolation="midpoint")
Q2=np.percentile(df["Low"],50,interpolation="midpoint")
Q3=np.percentile(df["Low"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Low"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Low']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Low']=up_lim
sns.boxplot(df["Low"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
microsoft_c=df
microsoft_c.to_csv("microsoft c.csv",index=False)

# %% [markdown]
# # 6. NETFLIX

# %%
df=pd.read_csv(r"Netflix.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   49.151428   50.331429   48.731430   49.848572   49.848572
# 1     2015-01-05   49.258572   49.258572   47.147144   47.311428   47.311428
# 2     2015-01-06   47.347141   47.639999   45.661430   46.501431   46.501431
# 3     2015-01-07   47.347141   47.421429   46.271427   46.742859   46.742859
# 4     2015-01-08   47.119999   47.835712   46.478573   47.779999   47.779999
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  603.359985  614.820007  602.630005  614.239990  614.239990
# 1757  2021-12-23  616.400024  616.880005  607.570007  614.090027  614.090027
# 1758  2021-12-27  615.000000  615.000000  609.250000  613.119995  613.119995
# 1759  2021-12-28  614.950012  618.409973  609.690002  610.710022  610.710022
# 1760  2021-12-29  610.710022  613.979980  604.679993  610.539978  610.539978
#
#         Volume
# 0     13475000
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean    287.221141   291.445354   282.820193   287.279744   287.279744
# std     169.408114   171.672770   166.981782   169.347855   169.347855
# min      46.021427    46.785713    45.264286    45.547142    45.547142
# 25%     120.099998   122.790001   118.089996   120.629997   120.629997
# 50%     291.940002   296.769989   287.450012   291.559998   291.559998
# 75%     404.690002   411.589996   394.850006   404.980011   404.980011
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.761000e+03
# mean   9.747929e+06
# std    8.084667e+06
# min    1.144000e+06
# 25%    4.787300e+06
# 50%    7.385700e+06
# 75%    1.193060e+07
# max    1.045009e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
c=[ 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
netflix_c=df
netflix_c.to_csv("netflix c.csv",index=False)

# %% [markdown]
# # 7. WALMART

# %%
df=pd.read_csv(r"Walmart.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   86.269997   86.720001   85.550003   85.900002   73.388664
# 1     2015-01-05   85.720001   86.320000   85.510002   85.650002   73.175095
# 2     2015-01-06   85.980003   86.750000   85.790001   86.309998   73.738953
# 3     2015-01-07   86.779999   88.680000   86.669998   88.599998   75.695427
# 4     2015-01-08   89.209999   90.669998   89.070000   90.470001   77.293053
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  139.899994  139.990005  138.529999  139.800003  139.800003
# 1757  2021-12-23  139.800003  140.160004  138.850006  139.490005  139.490005
# 1758  2021-12-27  139.600006  140.869995  139.570007  140.759995  140.759995
# 1759  2021-12-28  140.600006  142.970001  140.600006  142.779999  142.779999
# 1760  2021-12-29  142.660004  143.529999  142.320007  142.710007  142.710007
#
#         Volume
# 0      4501800
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1761.000000  1761.000000  1761.000000  1761.000000  1761.000000
# mean     98.967257    99.774872    98.216502    98.985599    93.493872
# std      27.619235    27.869452    27.365368    27.603646    29.997491
# min      56.389999    57.060001    56.299999    56.419998    49.131207
# 25%      73.430000    73.830002    73.059998    73.389999    65.350830
# 50%      94.500000    95.290001    93.820000    94.540001    89.093674
# 75%     119.919998   120.750000   119.019997   119.839996   116.259560
# max     153.600006   153.660004   151.660004   152.789993   150.842651
#
#              Volume
# count  1.761000e+03
# mean   8.605073e+06
# std    4.947665e+06
# min    2.227400e+06
# 25%    5.913500e+06
# 50%    7.330400e+06
# 75%    9.755400e+06
# max    8.089810e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1761 entries, 0 to 1760
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1761 non-null   object
#  1   Open       1761 non-null   float64
#  2   High       1761 non-null   float64
#  3   Low        1761 non-null   float64
#  4   Close      1761 non-null   float64
#  5   Adj Close  1761 non-null   float64
#  6   Volume     1761 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
for i in c:
    sns.boxplot(data=df[i])
    plt.show()

# %%
Q1=np.percentile(df["Volume"],25,interpolation="midpoint")
Q2=np.percentile(df["Volume"],50,interpolation="midpoint")
Q3=np.percentile(df["Volume"],75,interpolation="midpoint")
IQR=Q3-Q1
up_lim=Q3+1.5*IQR
outlier=[]
for x in df["Volume"]:
    if(x>up_lim):
        outlier.append(x) 
index1 = (df['Volume']>up_lim)
index1 = df.loc[index1].index
df.loc[list(index1),'Volume']=up_lim
sns.boxplot(df["Volume"])
# Out:
# c:\Users\Sreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
walmart_c=df
walmart_c.to_csv("walmart c.csv",index=False)

# %% [markdown]
# # Dropping unnecessary columns of all datasets

# %%
d1=pd.read_csv(r'amazon c.csv')
d2=pd.read_csv(r"apple c.csv")
d3=pd.read_csv(r"facebook c.csv")
d4=pd.read_csv(r"google c.csv")
d5=pd.read_csv(r"microsoft c.csv")
d6=pd.read_csv(r"netflix c.csv")
d7=pd.read_csv(r"walmart c.csv")

# %% [markdown]
# Amazon

# %%
d1
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-01-02   312.579987   314.750000   306.959991   308.519989
# 1     2015-01-05   307.010010   308.380005   300.850006   302.190002
# 2     2015-01-06   302.239990   303.000000   292.380005   295.290009
# 3     2015-01-07   297.500000   301.279999   295.329987   298.420013
# 4     2015-01-08   300.320007   303.140015   296.109985   300.459991
# ...          ...          ...          ...          ...          ...
# 1756  2021-12-22  3385.399902  3441.000000  3370.010010  3420.739990
# 1757  2021-12-23  3408.560059  3439.500000  3403.000000  3421.370117
# 1758  2021-12-27  3420.739990  3458.860107  3384.310059  3393.389893
# 1759  2021-12-28  3403.649902  3443.520020  3382.709961  3413.219971
# 1760  2021-12-29  3416.800049  3424.239990  3372.010010  3384.020020
#
#         Adj Close   Volume
# 0      308.519989  2783200
# 1      302.190002  2774200
# 2      295.290009  3519000
# ...

# %%
d1.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d1.rename(columns={'Open': 'Open_amazon', 'Close': 'Close_amazon'}, inplace=True)

# %%
d1
# Out:
#             Date  Open_amazon  Close_amazon
# 0     2015-01-02   312.579987    308.519989
# 1     2015-01-05   307.010010    302.190002
# 2     2015-01-06   302.239990    295.290009
# 3     2015-01-07   297.500000    298.420013
# 4     2015-01-08   300.320007    300.459991
# ...          ...          ...           ...
# 1756  2021-12-22  3385.399902   3420.739990
# 1757  2021-12-23  3408.560059   3421.370117
# 1758  2021-12-27  3420.739990   3393.389893
# 1759  2021-12-28  3403.649902   3413.219971
# 1760  2021-12-29  3416.800049   3384.020020
#
# [1761 rows x 3 columns]

# %%
d1.to_csv("amazon new.csv",index=False)

# %% [markdown]
# Apple

# %%
d2
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   27.847500   27.860001   26.837500   27.332500   24.745996
# 1     2015-01-05   27.072500   27.162500   26.352501   26.562500   24.048864
# 2     2015-01-06   26.635000   26.857500   26.157499   26.565001   24.051125
# 3     2015-01-07   26.799999   27.049999   26.674999   26.937500   24.388372
# 4     2015-01-08   27.307501   28.037500   27.174999   27.972500   25.325430
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  144.759995  147.253741  143.317505  146.231255  147.569941
# 1757  2021-12-23  144.759995  147.253741  143.317505  146.231255  147.569941
# 1758  2021-12-27  144.759995  147.253741  143.317505  146.231255  147.569941
# 1759  2021-12-28  144.759995  147.253741  143.317505  146.231255  147.569941
# 1760  2021-12-29  144.759995  147.253741  143.317505  146.231255  147.569941
#
#          Volume
# 0     212818400
# ...

# %%
d2.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d2.rename(columns={'Open': 'Open_apple', 'Close': 'Close_apple'}, inplace=True)

# %%
d2
# Out:
#             Date  Open_apple  Close_apple
# 0     2015-01-02   27.847500    27.332500
# 1     2015-01-05   27.072500    26.562500
# 2     2015-01-06   26.635000    26.565001
# 3     2015-01-07   26.799999    26.937500
# 4     2015-01-08   27.307501    27.972500
# ...          ...         ...          ...
# 1756  2021-12-22  144.759995   146.231255
# 1757  2021-12-23  144.759995   146.231255
# 1758  2021-12-27  144.759995   146.231255
# 1759  2021-12-28  144.759995   146.231255
# 1760  2021-12-29  144.759995   146.231255
#
# [1761 rows x 3 columns]

# %%
d2.to_csv("apple new.csv",index=False)

# %% [markdown]
# Facebook

# %%
d3
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   78.580002   78.930000   77.699997   78.449997   78.449997
# 1     2015-01-05   77.980003   79.250000   76.860001   77.190002   77.190002
# 2     2015-01-06   77.230003   77.589996   75.360001   76.150002   76.150002
# 3     2015-01-07   76.760002   77.360001   75.820000   76.150002   76.150002
# 4     2015-01-08   76.739998   78.230003   76.080002   78.180000   78.180000
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  333.799988  334.510010  328.260010  330.450012  330.450012
# 1757  2021-12-23  330.100006  336.670013  328.359985  335.239990  335.239990
# 1758  2021-12-27  338.850006  342.659984  338.010010  342.010009  342.010009
# 1759  2021-12-28  340.825008  342.659984  338.310020  342.010009  342.010009
# 1760  2021-12-29  340.825008  342.659984  338.310020  342.010009  342.010009
#
#         Volume
# 0     18177500
# ...

# %%
d3.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d3.rename(columns={'Open': 'Open_facebook', 'Close': 'Close_facebook'}, inplace=True)

# %%
d3
# Out:
#             Date  Open_facebook  Close_facebook
# 0     2015-01-02      78.580002       78.449997
# 1     2015-01-05      77.980003       77.190002
# 2     2015-01-06      77.230003       76.150002
# 3     2015-01-07      76.760002       76.150002
# 4     2015-01-08      76.739998       78.180000
# ...          ...            ...             ...
# 1756  2021-12-22     333.799988      330.450012
# 1757  2021-12-23     330.100006      335.239990
# 1758  2021-12-27     338.850006      342.010009
# 1759  2021-12-28     340.825008      342.010009
# 1760  2021-12-29     340.825008      342.010009
#
# [1761 rows x 3 columns]

# %%
d3.to_csv("facebook new.csv",index=False)

# %% [markdown]
# Google

# %%
d4
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-01-02   527.561584   529.815369   522.665039   523.373108
# 1     2015-01-05   521.827332   522.894409   511.655243   512.463013
# 2     2015-01-06   513.589966   514.761719   499.678131   500.585632
# 3     2015-01-07   505.611847   505.855164   498.281952   499.727997
# 4     2015-01-08   496.626526   502.101471   489.655640   501.303680
# ...          ...          ...          ...          ...          ...
# 1756  2021-12-22  2315.625123  2359.654847  2289.687471  2324.029908
# 1757  2021-12-23  2315.625123  2359.654847  2289.687471  2324.029908
# 1758  2021-12-27  2315.625123  2359.654847  2289.687471  2324.029908
# 1759  2021-12-28  2315.625123  2359.654847  2289.687471  2324.029908
# 1760  2021-12-29  2315.625123  2359.654847  2289.687471  2324.029908
#
#         Adj Close   Volume
# 0      523.373108  1447563
# 1      512.463013  2059840
# 2      500.585632  2899940
# ...

# %%
d4.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d4.rename(columns={'Open': 'Open_google', 'Close': 'Close_google'}, inplace=True)

# %%
d4
# Out:
#             Date  Open_google  Close_google
# 0     2015-01-02   527.561584    523.373108
# 1     2015-01-05   521.827332    512.463013
# 2     2015-01-06   513.589966    500.585632
# 3     2015-01-07   505.611847    499.727997
# 4     2015-01-08   496.626526    501.303680
# ...          ...          ...           ...
# 1756  2021-12-22  2315.625123   2324.029908
# 1757  2021-12-23  2315.625123   2324.029908
# 1758  2021-12-27  2315.625123   2324.029908
# 1759  2021-12-28  2315.625123   2324.029908
# 1760  2021-12-29  2315.625123   2324.029908
#
# [1761 rows x 3 columns]

# %%
d4.to_csv("google new.csv",index=False)

# %% [markdown]
# Microsoft

# %%
d5
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   46.660000   47.419998   46.540001   46.759998   41.193840
# 1     2015-01-05   46.369999   46.730000   46.250000   46.330002   40.815037
# 2     2015-01-06   46.380001   46.750000   45.540001   45.650002   40.215973
# 3     2015-01-07   45.980000   46.459999   45.490002   46.230000   40.726925
# 4     2015-01-08   46.750000   47.750000   46.720001   47.590000   41.925045
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  328.299988  333.609985  325.750000  333.200012  333.200012
# 1757  2021-12-23  332.750000  336.390015  332.730011  334.690002  334.690002
# 1758  2021-12-27  335.459991  342.480011  335.429993  342.450012  342.450012
# 1759  2021-12-28  343.149994  343.809998  340.320007  341.250000  341.250000
# 1760  2021-12-29  341.299988  344.299988  339.679993  341.950012  341.950012
#
#         Volume
# 0     27913900
# ...

# %%
d5.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d5.rename(columns={'Open': 'Open_microsoft', 'Close': 'Close_microsoft'}, inplace=True)

# %%
d5
# Out:
#             Date  Open_microsoft  Close_microsoft
# 0     2015-01-02       46.660000        46.759998
# 1     2015-01-05       46.369999        46.330002
# 2     2015-01-06       46.380001        45.650002
# 3     2015-01-07       45.980000        46.230000
# 4     2015-01-08       46.750000        47.590000
# ...          ...             ...              ...
# 1756  2021-12-22      328.299988       333.200012
# 1757  2021-12-23      332.750000       334.690002
# 1758  2021-12-27      335.459991       342.450012
# 1759  2021-12-28      343.149994       341.250000
# 1760  2021-12-29      341.299988       341.950012
#
# [1761 rows x 3 columns]

# %%
d5.to_csv("microsoft new.csv",index=False)

# %% [markdown]
# Netflix

# %%
d6
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   49.151428   50.331429   48.731430   49.848572   49.848572
# 1     2015-01-05   49.258572   49.258572   47.147144   47.311428   47.311428
# 2     2015-01-06   47.347141   47.639999   45.661430   46.501431   46.501431
# 3     2015-01-07   47.347141   47.421429   46.271427   46.742859   46.742859
# 4     2015-01-08   47.119999   47.835712   46.478573   47.779999   47.779999
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  603.359985  614.820007  602.630005  614.239990  614.239990
# 1757  2021-12-23  616.400024  616.880005  607.570007  614.090027  614.090027
# 1758  2021-12-27  615.000000  615.000000  609.250000  613.119995  613.119995
# 1759  2021-12-28  614.950012  618.409973  609.690002  610.710022  610.710022
# 1760  2021-12-29  610.710022  613.979980  604.679993  610.539978  610.539978
#
#         Volume
# 0     13475000
# ...

# %%
d6.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d6.rename(columns={'Open': 'Open_netflix', 'Close': 'Close_netflix'}, inplace=True)

# %%
d6
# Out:
#             Date  Open_netflix  Close_netflix
# 0     2015-01-02     49.151428      49.848572
# 1     2015-01-05     49.258572      47.311428
# 2     2015-01-06     47.347141      46.501431
# 3     2015-01-07     47.347141      46.742859
# 4     2015-01-08     47.119999      47.779999
# ...          ...           ...            ...
# 1756  2021-12-22    603.359985     614.239990
# 1757  2021-12-23    616.400024     614.090027
# 1758  2021-12-27    615.000000     613.119995
# 1759  2021-12-28    614.950012     610.710022
# 1760  2021-12-29    610.710022     610.539978
#
# [1761 rows x 3 columns]

# %%
d6.to_csv("netflix new.csv",index=False)

# %% [markdown]
# Walmart

# %%
d7
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-01-02   86.269997   86.720001   85.550003   85.900002   73.388664
# 1     2015-01-05   85.720001   86.320000   85.510002   85.650002   73.175095
# 2     2015-01-06   85.980003   86.750000   85.790001   86.309998   73.738953
# 3     2015-01-07   86.779999   88.680000   86.669998   88.599998   75.695427
# 4     2015-01-08   89.209999   90.669998   89.070000   90.470001   77.293053
# ...          ...         ...         ...         ...         ...         ...
# 1756  2021-12-22  139.899994  139.990005  138.529999  139.800003  139.800003
# 1757  2021-12-23  139.800003  140.160004  138.850006  139.490005  139.490005
# 1758  2021-12-27  139.600006  140.869995  139.570007  140.759995  140.759995
# 1759  2021-12-28  140.600006  142.970001  140.600006  142.779999  142.779999
# 1760  2021-12-29  142.660004  143.529999  142.320007  142.710007  142.710007
#
#         Volume
# 0      4501800
# ...

# %%
d7.drop(['High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
d7.rename(columns={'Open': 'Open_walmart', 'Close': 'Close_walmart'}, inplace=True)

# %%
d7
# Out:
#             Date  Open_walmart  Close_walmart
# 0     2015-01-02     86.269997      85.900002
# 1     2015-01-05     85.720001      85.650002
# 2     2015-01-06     85.980003      86.309998
# 3     2015-01-07     86.779999      88.599998
# 4     2015-01-08     89.209999      90.470001
# ...          ...           ...            ...
# 1756  2021-12-22    139.899994     139.800003
# 1757  2021-12-23    139.800003     139.490005
# 1758  2021-12-27    139.600006     140.759995
# 1759  2021-12-28    140.600006     142.779999
# 1760  2021-12-29    142.660004     142.710007
#
# [1761 rows x 3 columns]

# %%
d7.to_csv("walmart new.csv",index=False)
